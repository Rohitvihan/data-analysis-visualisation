# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(color_codes=True)

dataset=pd.read_csv('car_insurance.csv')
dataset.dtypes
# Out:
# id                       int64
# age                      int64
# gender                   int64
# driving_experience      object
# education               object
# income                  object
# credit_score           float64
# vehicle_ownership      float64
# vehicle_year            object
# married                float64
# children               float64
# postal_code              int64
# annual_mileage         float64
# vehicle_type            object
# speeding_violations      int64
# duis                     int64
# past_accidents           int64
# outcome                float64
# dtype: object

# %%
dataset.describe(include="all")
# Out:
#                    id           age        gender driving_experience  \
# count    10000.000000  10000.000000  10000.000000              10000
# unique            NaN           NaN           NaN                  4
# top               NaN           NaN           NaN               0-9y
# freq              NaN           NaN           NaN               3530
# mean    500521.906800      1.489500      0.499000                NaN
# std     290030.768758      1.025278      0.500024                NaN
# min        101.000000      0.000000      0.000000                NaN
# 25%     249638.500000      1.000000      0.000000                NaN
# 50%     501777.000000      1.000000      0.000000                NaN
# 75%     753974.500000      2.000000      1.000000                NaN
# max     999976.000000      3.000000      1.000000                NaN
#
#           education       income  credit_score  vehicle_ownership  \
# count         10000        10000   9018.000000       10000.000000
# ...

# %%
dataset.columns
# Out:
# Index(['id', 'age', 'gender', 'driving_experience', 'education', 'income',
#        'credit_score', 'vehicle_ownership', 'vehicle_year', 'married',
#        'children', 'postal_code', 'annual_mileage', 'vehicle_type',
#        'speeding_violations', 'duis', 'past_accidents', 'outcome'],
#       dtype='object')

# %%
dataset.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'id'}>, <Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'gender'}>,
#         <Axes: title={'center': 'credit_score'}>],
#        [<Axes: title={'center': 'vehicle_ownership'}>,
#         <Axes: title={'center': 'married'}>,
#         <Axes: title={'center': 'children'}>,
#         <Axes: title={'center': 'postal_code'}>],
#        [<Axes: title={'center': 'annual_mileage'}>,
#         <Axes: title={'center': 'speeding_violations'}>,
#         <Axes: title={'center': 'duis'}>,
#         <Axes: title={'center': 'past_accidents'}>],
#        [<Axes: title={'center': 'outcome'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
dataset.head()
# Out:
#        id  age  gender driving_experience    education         income  \
# 0  569520    3       0               0-9y  high school    upper class
# 1  750365    0       1               0-9y         none        poverty
# 2  199901    0       0               0-9y  high school  working class
# 3  478866    0       1               0-9y   university  working class
# 4  731664    1       1             10-19y         none  working class
#
#    credit_score  vehicle_ownership vehicle_year  married  children  \
# 0      0.629027                1.0   after 2015      0.0       1.0
# 1      0.357757                0.0  before 2015      0.0       0.0
# 2      0.493146                1.0  before 2015      0.0       0.0
# 3      0.206013                1.0  before 2015      0.0       1.0
# 4      0.388366                1.0  before 2015      0.0       0.0
#
#    postal_code  annual_mileage vehicle_type  speeding_violations  duis  \
# ...

# %%
sns.boxplot(x='driving_experience',y='credit_score',data=dataset)
# Out:
# <Axes: xlabel='driving_experience', ylabel='credit_score'>

# %%
import seaborn as sns
import pandas as pd
dataset=pd.read_csv('car_insurance.csv')
sns.pairplot(dataset)#to visualize relationships between multiple variables in a dataset
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
dr=dataset.drop(['id', 'age', 'gender', 'driving_experience', 'education', 'income',
       'credit_score', 'vehicle_ownership', 'vehicle_year', 'married'],axis=1)
dr

# %%
upd=dataset.rename(columns={'id':'r_no', 'age':'ag_bar', 'gender':'gen','driving_experience':'dri_exp', 'education':'edu', 'income':'inc'})
upd
# Out:
#         r_no  ag_bar  gen dri_exp          edu            inc  credit_score  \
# 0     569520       3    0    0-9y  high school    upper class      0.629027
# 1     750365       0    1    0-9y         none        poverty      0.357757
# 2     199901       0    0    0-9y  high school  working class      0.493146
# 3     478866       0    1    0-9y   university  working class      0.206013
# 4     731664       1    1  10-19y         none  working class      0.388366
# ...      ...     ...  ...     ...          ...            ...           ...
# 9995  323164       1    0  10-19y   university    upper class      0.582787
# 9996  910346       1    0  10-19y         none   middle class      0.522231
# 9997  468409       1    1    0-9y  high school   middle class      0.470940
# 9998  903459       1    0  10-19y  high school        poverty      0.364185
# 9999  442696       1    0    0-9y         none  working class      0.435225
#
# ...

# %%
dataset.shape
# Out:
# (10000, 18)

# %%
duplicate=dataset[dataset.duplicated()]# filters only the duplicate rows
print(duplicate.sum())
# Out:
# id                       0
# age                      0
# gender                   0
# driving_experience       0
# education                0
# income                   0
# credit_score           0.0
# vehicle_ownership      0.0
# vehicle_year             0
# married                0.0
# children               0.0
# postal_code              0
# annual_mileage         0.0
# vehicle_type             0
# speeding_violations      0
# duis                     0
# past_accidents           0
# outcome                0.0
# dtype: object

# %%
#count the rows 
dataset.count()
# Out:
# id                     10000
# age                    10000
# gender                 10000
# driving_experience     10000
# education              10000
# income                 10000
# credit_score            9018
# vehicle_ownership      10000
# vehicle_year           10000
# married                10000
# children               10000
# postal_code            10000
# annual_mileage          9043
# vehicle_type           10000
# speeding_violations    10000
# duis                   10000
# past_accidents         10000
# outcome                10000
# dtype: int64

# %%
dataset=dataset.drop_duplicates()
dataset.count()
# Out:
# id                     10000
# age                    10000
# gender                 10000
# driving_experience     10000
# education              10000
# income                 10000
# credit_score            9018
# vehicle_ownership      10000
# vehicle_year           10000
# married                10000
# children               10000
# postal_code            10000
# annual_mileage          9043
# vehicle_type           10000
# speeding_violations    10000
# duis                   10000
# past_accidents         10000
# outcome                10000
# dtype: int64

# %%
data_null=dataset.isnull().sum()
data_null
# Out:
# id                       0
# age                      0
# gender                   0
# driving_experience       0
# education                0
# income                   0
# credit_score           982
# vehicle_ownership        0
# vehicle_year             0
# married                  0
# children                 0
# postal_code              0
# annual_mileage         957
# vehicle_type             0
# speeding_violations      0
# duis                     0
# past_accidents           0
# outcome                  0
# dtype: int64

# %%
dta_fill=dataset.dropna()#drop nrows having null values
dta_fill.count()
# Out:
# id                     8149
# age                    8149
# gender                 8149
# driving_experience     8149
# education              8149
# income                 8149
# credit_score           8149
# vehicle_ownership      8149
# vehicle_year           8149
# married                8149
# children               8149
# postal_code            8149
# annual_mileage         8149
# vehicle_type           8149
# speeding_violations    8149
# duis                   8149
# past_accidents         8149
# outcome                8149
# dtype: int64

# %%
print(dta_fill.isnull().sum())
# Out:
# id                     0
# age                    0
# gender                 0
# driving_experience     0
# education              0
# income                 0
# credit_score           0
# vehicle_ownership      0
# vehicle_year           0
# married                0
# children               0
# postal_code            0
# annual_mileage         0
# vehicle_type           0
# speeding_violations    0
# duis                   0
# past_accidents         0
# outcome                0
# dtype: int64

# %%
sns.boxplot(x=dataset['id'])
# Out:
# <Axes: xlabel='id'>
